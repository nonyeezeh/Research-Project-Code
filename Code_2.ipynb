# %% [markdown]
# <a href="https://colab.research.google.com/github/nonyeezeh/Research-Project-Code/blob/main/Code_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Data Generation

# %% [markdown]
# ### Forward Sampling

# %%
import numpy as np
import pandas as pd

# Define the number of samples
num_samples = 10000

# Define the possible values for each variable
values = {
    'IR': ['low', 'medium', 'high'],
    'EI': ['poor', 'average', 'good'],
    'Inf': ['low', 'medium', 'high'],
    'MS': ['negative', 'neutral', 'positive'],
    'CP': ['poor', 'average', 'good'],
    'GEC': ['poor', 'average', 'good'],
    'GP': ['restrictive', 'neutral', 'supportive'],
    'PS': ['unstable', 'neutral', 'stable'],
    'CC': ['low', 'medium', 'high'],
    'FI': ['low', 'medium', 'high'],
    'SP': ['decrease', 'stable', 'increase']
}

# Function to sample Interest Rates (IR) given Government Policies (GP)
def sample_IR(gp):
    if gp == 'restrictive':
        return np.random.choice(values['IR'], p=[0.5, 0.3, 0.2])
    elif gp == 'neutral':
        return np.random.choice(values['IR'], p=[0.3, 0.4, 0.3])
    else:
        return np.random.choice(values['IR'], p=[0.2, 0.3, 0.5])

# Function to sample Economic Indicators (EI) given Interest Rates (IR) and Government Policies (GP)
def sample_EI(ir, gp):
    if gp == 'restrictive':
        if ir == 'low':
            return np.random.choice(values['EI'], p=[0.4, 0.4, 0.2])
        elif ir == 'medium':
            return np.random.choice(values['EI'], p=[0.5, 0.3, 0.2])
        else:
            return np.random.choice(values['EI'], p=[0.6, 0.2, 0.2])
    elif gp == 'neutral':
        if ir == 'low':
            return np.random.choice(values['EI'], p=[0.3, 0.5, 0.2])
        elif ir == 'medium':
            return np.random.choice(values['EI'], p=[0.4, 0.4, 0.2])
        else:
            return np.random.choice(values['EI'], p=[0.5, 0.3, 0.2])
    else:
        if ir == 'low':
            return np.random.choice(values['EI'], p=[0.2, 0.5, 0.3])
        elif ir == 'medium':
            return np.random.choice(values['EI'], p=[0.3, 0.5, 0.2])
        else:
            return np.random.choice(values['EI'], p=[0.4, 0.4, 0.2])

# Function to sample Inflation Rate (Inf) given Interest Rates (IR)
def sample_Inf(ir):
    if ir == 'low':
        return np.random.choice(values['Inf'], p=[0.6, 0.3, 0.1])
    elif ir == 'medium':
        return np.random.choice(values['Inf'], p=[0.3, 0.4, 0.3])
    else:
        return np.random.choice(values['Inf'], p=[0.1, 0.3, 0.6])

# Function to sample Market Sentiment (MS) given Economic Indicators (EI)
def sample_MS(ei):
    if ei == 'poor':
        return np.random.choice(values['MS'], p=[0.6, 0.3, 0.1])
    elif ei == 'average':
        return np.random.choice(values['MS'], p=[0.3, 0.4, 0.3])
    else:
        return np.random.choice(values['MS'], p=[0.1, 0.3, 0.6])

# Function to sample Company Performance (CP) given Economic Indicators (EI) and Global Economic Conditions (GEC)
def sample_CP(ei, gec):
    if ei == 'poor':
        if gec == 'poor':
            return np.random.choice(values['CP'], p=[0.7, 0.2, 0.1])
        elif gec == 'average':
            return np.random.choice(values['CP'], p=[0.6, 0.3, 0.1])
        else:
            return np.random.choice(values['CP'], p=[0.5, 0.4, 0.1])
    elif ei == 'average':
        if gec == 'poor':
            return np.random.choice(values['CP'], p=[0.5, 0.4, 0.1])
        elif gec == 'average':
            return np.random.choice(values['CP'], p=[0.4, 0.4, 0.2])
        else:
            return np.random.choice(values['CP'], p=[0.3, 0.5, 0.2])
    else:
        if gec == 'poor':
            return np.random.choice(values['CP'], p=[0.4, 0.4, 0.2])
        elif gec == 'average':
            return np.random.choice(values['CP'], p=[0.3, 0.5, 0.2])
        else:
            return np.random.choice(values['CP'], p=[0.2, 0.5, 0.3])

# Function to sample Global Economic Conditions (GEC) given Government Policies (GP)
def sample_GEC(gp):
    if gp == 'restrictive':
        return np.random.choice(values['GEC'], p=[0.5, 0.3, 0.2])
    elif gp == 'neutral':
        return np.random.choice(values['GEC'], p=[0.3, 0.4, 0.3])
    else:
        return np.random.choice(values['GEC'], p=[0.2, 0.3, 0.5])

# Function to sample Government Policies (GP)
def sample_GP():
    return np.random.choice(values['GP'], p=[0.3, 0.4, 0.3])

# Function to sample Political Stability (PS) given Government Policies (GP)
def sample_PS(gp):
    if gp == 'restrictive':
        return np.random.choice(values['PS'], p=[0.5, 0.3, 0.2])
    elif gp == 'neutral':
        return np.random.choice(values['PS'], p=[0.3, 0.4, 0.3])
    else:
        return np.random.choice(values['PS'], p=[0.2, 0.3, 0.5])

# Function to sample Consumer Confidence (CC) given Economic Indicators (EI) and Inflation Rate (Inf)
def sample_CC(ei, inf):
    if ei == 'poor':
        if inf == 'low':
            return np.random.choice(values['CC'], p=[0.4, 0.4, 0.2])
        elif inf == 'medium':
            return np.random.choice(values['CC'], p=[0.5, 0.3, 0.2])
        else:
            return np.random.choice(values['CC'], p=[0.6, 0.2, 0.2])
    elif ei == 'average':
        if inf == 'low':
            return np.random.choice(values['CC'], p=[0.3, 0.5, 0.2])
        elif inf == 'medium':
            return np.random.choice(values['CC'], p=[0.4, 0.4, 0.2])
        else:
            return np.random.choice(values['CC'], p=[0.5, 0.3, 0.2])
    else:
        if inf == 'low':
            return np.random.choice(values['CC'], p=[0.2, 0.5, 0.3])
        elif inf == 'medium':
            return np.random.choice(values['CC'], p=[0.3, 0.5, 0.2])
        else:
            return np.random.choice(values['CC'], p=[0.4, 0.4, 0.2])

# Function to sample Foreign Investment (FI) given Global Economic Conditions (GEC), Political Stability (PS), and Interest Rates (IR)
def sample_FI(gec, ps, ir):
    if gec == 'poor':
        if ps == 'unstable':
            if ir == 'low':
                return np.random.choice(values['FI'], p=[0.5, 0.3, 0.2])
            elif ir == 'medium':
                return np.random.choice(values['FI'], p=[0.6, 0.2, 0.2])
            else:
                return np.random.choice(values['FI'], p=[0.7, 0.2, 0.1])
        elif ps == 'neutral':
            if ir == 'low':
                return np.random.choice(values['FI'], p=[0.4, 0.4, 0.2])
            elif ir == 'medium':
                return np.random.choice(values['FI'], p=[0.5, 0.3, 0.2])
            else:
                return np.random.choice(values['FI'], p=[0.6, 0.3, 0.1])
        else:
            if ir == 'low':
                return np.random.choice(values['FI'], p=[0.3, 0.5, 0.2])
            elif ir == 'medium':
                return np.random.choice(values['FI'], p=[0.4, 0.4, 0.2])
            else:
                return np.random.choice(values['FI'], p=[0.5, 0.4, 0.1])
    elif gec == 'average':
        if ps == 'unstable':
            if ir == 'low':
                return np.random.choice(values['FI'], p=[0.4, 0.4, 0.2])
            elif ir == 'medium':
                return np.random.choice(values['FI'], p=[0.5, 0.3, 0.2])
            else:
                return np.random.choice(values['FI'], p=[0.6, 0.3, 0.1])
        elif ps == 'neutral':
            if ir == 'low':
                return np.random.choice(values['FI'], p=[0.3, 0.5, 0.2])
            elif ir == 'medium':
                return np.random.choice(values['FI'], p=[0.4, 0.4, 0.2])
            else:
                return np.random.choice(values['FI'], p=[0.5, 0.3, 0.2])
        else:
            if ir == 'low':
                return np.random.choice(values['FI'], p=[0.2, 0.5, 0.3])
            elif ir == 'medium':
                return np.random.choice(values['FI'], p=[0.3, 0.5, 0.2])
            else:
                return np.random.choice(values['FI'], p=[0.4, 0.4, 0.2])
    else:
        if ps == 'unstable':
            if ir == 'low':
                return np.random.choice(values['FI'], p=[0.3, 0.5, 0.2])
            elif ir == 'medium':
                return np.random.choice(values['FI'], p=[0.4, 0.4, 0.2])
            else:
                return np.random.choice(values['FI'], p=[0.5, 0.4, 0.1])
        elif ps == 'neutral':
            if ir == 'low':
                return np.random.choice(values['FI'], p=[0.2, 0.5, 0.3])
            elif ir == 'medium':
                return np.random.choice(values['FI'], p=[0.3, 0.5, 0.2])
            else:
                return np.random.choice(values['FI'], p=[0.4, 0.4, 0.2])
        else:
            if ir == 'low':
                return np.random.choice(values['FI'], p=[0.1, 0.5, 0.4])
            elif ir == 'medium':
                return np.random.choice(values['FI'], p=[0.2, 0.5, 0.3])
            else:
                return np.random.choice(values['FI'], p=[0.3, 0.5, 0.2])

# Function to sample Stock Prices (SP) given Market Sentiment (MS), Company Performance (CP), Consumer Confidence (CC), and Foreign Investment (FI)
def sample_SP(ms, cp, cc, fi):
    if ms == 'negative':
        if cp == 'poor':
            if cc == 'low' and fi == 'low':
                return np.random.choice(values['SP'], p=[0.7, 0.2, 0.1])
            elif cc == 'medium' and fi == 'medium':
                return np.random.choice(values['SP'], p=[0.6, 0.3, 0.1])
            else:
                return np.random.choice(values['SP'], p=[0.5, 0.4, 0.1])
        elif cp == 'average':
            if cc == 'low' and fi == 'low':
                return np.random.choice(values['SP'], p=[0.6, 0.3, 0.1])
            elif cc == 'medium' and fi == 'medium':
                return np.random.choice(values['SP'], p=[0.5, 0.4, 0.1])
            else:
                return np.random.choice(values['SP'], p=[0.4, 0.4, 0.2])
        else:
            if cc == 'low' and fi == 'low':
                return np.random.choice(values['SP'], p=[0.5, 0.4, 0.1])
            elif cc == 'medium' and fi == 'medium':
                return np.random.choice(values['SP'], p=[0.4, 0.4, 0.2])
            else:
                return np.random.choice(values['SP'], p=[0.3, 0.5, 0.2])
    elif ms == 'neutral':
        if cp == 'poor':
            if cc == 'low' and fi == 'low':
                return np.random.choice(values['SP'], p=[0.6, 0.3, 0.1])
            elif cc == 'medium' and fi == 'medium':
                return np.random.choice(values['SP'], p=[0.5, 0.4, 0.1])
            else:
                return np.random.choice(values['SP'], p=[0.4, 0.4, 0.2])
        elif cp == 'average':
            if cc == 'low' and fi == 'low':
                return np.random.choice(values['SP'], p=[0.5, 0.4, 0.1])
            elif cc == 'medium' and fi == 'medium':
                return np.random.choice(values['SP'], p=[0.4, 0.4, 0.2])
            else:
                return np.random.choice(values['SP'], p=[0.3, 0.5, 0.2])
        else:
            if cc == 'low' and fi == 'low':
                return np.random.choice(values['SP'], p=[0.4, 0.4, 0.2])
            elif cc == 'medium' and fi == 'medium':
                return np.random.choice(values['SP'], p=[0.3, 0.5, 0.2])
            else:
                return np.random.choice(values['SP'], p=[0.2, 0.5, 0.3])
    else:
        if cp == 'poor':
            if cc == 'low' and fi == 'low':
                return np.random.choice(values['SP'], p=[0.5, 0.4, 0.1])
            elif cc == 'medium' and fi == 'medium':
                return np.random.choice(values['SP'], p=[0.4, 0.4, 0.2])
            else:
                return np.random.choice(values['SP'], p=[0.3, 0.5, 0.2])
        elif cp == 'average':
            if cc == 'low' and fi == 'low':
                return np.random.choice(values['SP'], p=[0.4, 0.4, 0.2])
            elif cc == 'medium' and fi == 'medium':
                return np.random.choice(values['SP'], p=[0.3, 0.5, 0.2])
            else:
                return np.random.choice(values['SP'], p=[0.2, 0.5, 0.3])
        else:
            if cc == 'low' and fi == 'low':
                return np.random.choice(values['SP'], p=[0.3, 0.5, 0.2])
            elif cc == 'medium' and fi == 'medium':
                return np.random.choice(values['SP'], p=[0.2, 0.5, 0.3])
            else:
                return np.random.choice(values['SP'], p=[0.1, 0.5, 0.4])

# Generate the data
data = []

for _ in range(num_samples):
    gp = sample_GP()
    ir = sample_IR(gp)
    ei = sample_EI(ir, gp)
    inf = sample_Inf(ir)
    ms = sample_MS(ei)
    gec = sample_GEC(gp)
    cp = sample_CP(ei, gec)
    ps = sample_PS(gp)
    cc = sample_CC(ei, inf)
    fi = sample_FI(gec, ps, ir)
    sp = sample_SP(ms, cp, cc, fi)

    data.append([ir, ei, inf, ms, cp, gec, gp, ps, cc, fi, sp])

# Convert to DataFrame
df = pd.DataFrame(data, columns=['IR', 'EI', 'Inf', 'MS', 'CP', 'GEC', 'GP', 'PS', 'CC', 'FI', 'SP'])

# Save the DataFrame to a CSV file
df.to_csv('bayesian_network_data_Forward_sampling.csv', index=False)

print(df.head())
# Out:
#        IR    EI     Inf        MS       CP      GEC           GP       PS  \
# 0    high  poor  medium  negative     poor  average   supportive   stable
# 1  medium  poor  medium  negative     poor     poor  restrictive   stable
# 2    high  poor    high  negative     poor     poor      neutral  neutral
# 3    high  poor  medium  negative  average     good      neutral   stable
# 4     low  poor  medium  negative     poor     poor      neutral  neutral
#
#     CC      FI        SP
# 0  low     low  decrease
# 1  low  medium    stable
# 2  low  medium    stable
# 3  low     low  decrease
# 4  low    high  decrease

# %% [markdown]
# # Neural Network Training

# %% [markdown]
# ### FNN

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('bayesian_network_data_Forward_sampling.csv')

# One-hot encode categorical variables
encoder = OneHotEncoder(sparse=False)
encoded_features = encoder.fit_transform(df[['IR', 'EI', 'Inf', 'MS', 'CP', 'GEC', 'GP', 'PS', 'CC', 'FI']])
encoded_labels = encoder.fit_transform(df[['SP']])

# Define the neural network
model = Sequential([
    Dense(10, input_shape=(encoded_features.shape[1],), activation='relu'),
    Dense(10, activation='relu'),
    Dense(encoded_labels.shape[1], activation='softmax')  # Output layer with softmax activation for classification
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(encoded_features, encoded_labels, epochs=50, batch_size=32, validation_split=0.2)

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Print the final accuracy on the training data
train_loss, train_accuracy = model.evaluate(encoded_features, encoded_labels, verbose=0)
print(f'Training accuracy: {train_accuracy:.4f}')

# Make predictions on the entire dataset
predictions = model.predict(encoded_features)

# Convert predictions from probabilities to class labels
predicted_classes = encoder.inverse_transform(predictions)

# Convert true labels from one-hot encoded format to class labels
true_classes = encoder.inverse_transform(encoded_labels)

# Print a few examples of predictions and true labels
for i in range(10):
    print(f"True: {true_classes[i]}, Predicted: {predicted_classes[i]}")

# Convert predicted_classes to a suitable format for DataFrame
predicted_classes_series = pd.Series([pred[0] for pred in predicted_classes], name='Predicted SP')

# Save predictions to a new CSV file
output_df = df.copy()
output_df['Predicted SP'] = predicted_classes_series
output_df.to_csv('nn_predicted_data.csv', index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Epoch 1/50
# 250/250 [==============================] - 3s 5ms/step - loss: 1.0945 - accuracy: 0.4140 - val_loss: 1.0363 - val_accuracy: 0.4575
# Epoch 2/50
# 250/250 [==============================] - 1s 4ms/step - loss: 1.0333 - accuracy: 0.4589 - val_loss: 1.0236 - val_accuracy: 0.4615
# Epoch 3/50
# 250/250 [==============================] - 1s 3ms/step - loss: 1.0222 - accuracy: 0.4651 - val_loss: 1.0162 - val_accuracy: 0.4670
# Epoch 4/50
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Load the data
df = pd.read_csv('bayesian_network_data_Forward_sampling.csv')

# One-hot encode categorical variables
# This process converts categorical features into a format that can be used for training the model.
encoder = OneHotEncoder(sparse=False)
encoded_features = encoder.fit_transform(df[['IR', 'EI', 'Inf', 'MS', 'CP', 'GEC', 'GP', 'PS', 'CC', 'FI']])
encoded_labels = encoder.fit_transform(df[['SP']])

# Function to build and train the model
def build_and_train_model(layers, neurons, input_shape):
    """
    Build and train a neural network with the specified number of layers and neurons.

    Parameters:
    layers (int): Number of hidden layers.
    neurons (int): Number of neurons in each hidden layer.
    input_shape (int): Number of input features.

    Returns:
    model (Sequential): Trained neural network model.
    history (History): Training history object containing training and validation loss and accuracy.
    """
    model = Sequential()
    # Input layer and first hidden layer
    model.add(Dense(neurons, input_shape=(input_shape,), activation='relu'))

    # Additional hidden layers
    for _ in range(layers - 1):
        model.add(Dense(neurons, activation='relu'))

    # Output layer with softmax activation for classification
    model.add(Dense(encoded_labels.shape[1], activation='softmax'))

    # Compile the model with the Adam optimizer and categorical crossentropy loss function
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Train the model
    history = model.fit(encoded_features, encoded_labels, epochs=50, batch_size=32, validation_split=0.2, verbose=0)

    return model, history

# Function to calculate BIC
def calculate_bic(model, n, loss):
    """
    Calculate the Bayesian Information Criterion (BIC) for the model.

    Parameters:
    model (Sequential): Trained neural network model.
    n (int): Number of data points.
    loss (float): Final validation loss value.

    Returns:
    bic (float): BIC value.
    """
    k = model.count_params()  # Number of parameters in the model
    bic = n * np.log(loss / n) + k * np.log(n)
    return bic

# Train and evaluate different models
n = encoded_features.shape[0]  # Number of data points
results = []

# Iterate over different numbers of layers and neurons to find the best architecture
for layers in [1, 2, 3]:  # Number of hidden layers
    for neurons in [10, 20, 30]:  # Number of neurons per hidden layer
        model, history = build_and_train_model(layers, neurons, encoded_features.shape[1])

        # Use the final validation loss and scale by the number of data points
        loss = history.history['val_loss'][-1] * n

        # Calculate BIC
        bic = calculate_bic(model, n, loss)

        # Store the results
        results.append((layers, neurons, bic, model, history))

# Find the best model with the lowest BIC
best_model_config = min(results, key=lambda x: x[2])
best_model = best_model_config[3]
best_history = best_model_config[4]

# Print the best model configuration
print(f"Best Model Configuration: Layers: {best_model_config[0]}, Neurons: {best_model_config[1]}, BIC: {best_model_config[2]}")

# Print the model accuracy
best_model_accuracy = best_history.history['val_accuracy'][-1]
print(f"Best Model Validation Accuracy: {best_model_accuracy}")

# Make predictions on the entire dataset with the best model
predictions = best_model.predict(encoded_features)

# Convert predictions from probabilities to class labels
predicted_classes = encoder.inverse_transform(predictions)

# Convert true labels from one-hot encoded format to class labels
true_classes = encoder.inverse_transform(encoded_labels)

# Print a few examples of predictions and true labels
for i in range(10):
    print(f"True: {true_classes[i]}, Predicted: {predicted_classes[i]}")

# Convert predicted_classes to a suitable format for DataFrame
predicted_classes_series = pd.Series([pred[0] for pred in predicted_classes], name='Predicted SP')

# Save predictions to a new CSV file
output_df = df.copy()
output_df['Predicted SP'] = predicted_classes_series
output_df.to_csv('nn_predicted_data_with_bic.csv', index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Best Model Configuration: Layers: 1, Neurons: 10, BIC: 3180.567156506853
# Best Model Validation Accuracy: 0.48249998688697815
# 313/313 [==============================] - 0s 1ms/step
# True: ['stable'], Predicted: ['stable']
# True: ['decrease'], Predicted: ['decrease']
# True: ['decrease'], Predicted: ['stable']
# True: ['decrease'], Predicted: ['decrease']
# True: ['stable'], Predicted: ['stable']
# True: ['decrease'], Predicted: ['stable']
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('bayesian_network_data_Forward_sampling.csv')

# One-hot encode categorical variables
encoder = OneHotEncoder(sparse=False)
encoded_features = encoder.fit_transform(df[['IR', 'EI', 'Inf', 'MS', 'CP', 'GEC', 'GP', 'PS', 'CC', 'FI']])
encoded_labels = encoder.fit_transform(df[['SP']])

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(encoded_features, encoded_labels, test_size=0.2, random_state=42)

def build_and_train_model(layers, neurons, input_shape):
    model = Sequential()
    model.add(Dense(neurons, input_shape=(input_shape,), activation='relu'))
    for _ in range(layers - 1):
        model.add(Dense(neurons, activation='relu'))
    model.add(Dense(encoded_labels.shape[1], activation='softmax'))

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val), verbose=0)
    return model, history

def calculate_bic(model, n, loss):
    p = sum([np.prod(w.shape) for w in model.trainable_weights])  # Number of parameters
    return n * np.log(loss) + p * np.log(n)

# Iterate over different numbers of layers and neurons to find the best architecture
results = []
n = X_val.shape[0]  # Number of validation samples
for layers in [1, 2, 3]:  # Number of hidden layers
    for neurons in [10, 20, 30]:  # Number of neurons per hidden layer
        model, history = build_and_train_model(layers, neurons, encoded_features.shape[1])

        # Use the final validation loss and scale by the number of data points
        loss = history.history['val_loss'][-1] * n

        # Calculate BIC
        bic = calculate_bic(model, n, loss)

        # Store the results
        results.append((layers, neurons, bic, model, history))

        # Print the current model configuration and its BIC
        print(f"Model with {layers} layers and {neurons} neurons per layer has BIC: {bic}")

        # Make predictions on the validation set
        predictions = model.predict(X_val)
        predicted_classes = encoder.inverse_transform(predictions)
        true_classes = encoder.inverse_transform(y_val)

        # Print a few examples of predictions and true labels for this configuration
        for i in range(5):
            print(f"True: {true_classes[i]}, Predicted: {predicted_classes[i]}")

        # Save predictions to a CSV file for this model configuration
        predicted_classes_series = pd.Series([pred[0] for pred in predicted_classes], name='Predicted SP')
        output_df = df.copy()
        output_df['Predicted SP'] = predicted_classes_series
        output_filename = f'nn_predictions_layers_{layers}_neurons_{neurons}.csv'
        output_df.to_csv(output_filename, index=False)
        print(f"Predictions saved to '{output_filename}'")

# Find the best model based on BIC
best_model_info = min(results, key=lambda x: x[2])
best_layers, best_neurons, best_bic, best_model, best_history = best_model_info

# Print the best model configuration and its BIC
print(f"\nBest Model Configuration: Layers: {best_layers}, Neurons: {best_neurons}, BIC: {best_bic}")
print(f"Best Model Validation Accuracy: {max(best_history.history['val_accuracy'])}")

# Make predictions on the entire dataset using the best model
predictions = best_model.predict(encoded_features)
predicted_classes = encoder.inverse_transform(predictions)
true_classes = encoder.inverse_transform(encoded_labels)

# Print a few examples of predictions and true labels for the best model
for i in range(10):
    print(f"True: {true_classes[i]}, Predicted: {predicted_classes[i]}")

# Convert predicted_classes to a suitable format for DataFrame
predicted_classes_series = pd.Series([pred[0] for pred in predicted_classes], name='Predicted SP')

# Save predictions of the best model to a new CSV file
output_df = df.copy()
output_df['Predicted SP'] = predicted_classes_series
output_df.to_csv('nn_predicted_data_best_model.csv', index=False)

print("Predictions saved to 'nn_predicted_data_best_model.csv'")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Model with 1 layers and 10 neurons per layer has BIC: 17831.03423549947
# 63/63 [==============================] - 0s 2ms/step
# True: ['stable'], Predicted: ['decrease']
# True: ['stable'], Predicted: ['stable']
# True: ['stable'], Predicted: ['stable']
# True: ['increase'], Predicted: ['stable']
# True: ['decrease'], Predicted: ['decrease']
# Predictions saved to 'nn_predictions_layers_1_neurons_10.csv'
# ...

# %%
pip install shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.1/540.1 kB 3.5 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt
import shap

# Load the data
df = pd.read_csv('bayesian_network_data_Forward_sampling.csv')

# One-hot encode categorical variables
encoder = OneHotEncoder(sparse=False)
encoded_features = encoder.fit_transform(df[['IR', 'EI', 'Inf', 'MS', 'CP', 'GEC', 'GP', 'PS', 'CC', 'FI']])
encoded_labels = encoder.fit_transform(df[['SP']])

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(encoded_features, encoded_labels, test_size=0.2, random_state=42)

# Define the neural network
model = Sequential([
    Dense(10, input_shape=(encoded_features.shape[1],), activation='relu'),
    Dense(10, activation='relu'),
    Dense(encoded_labels.shape[1], activation='softmax')  # Output layer with softmax activation for classification
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Evaluate the model
loss, accuracy = model.evaluate(X_val, y_val)
print(f'Validation Accuracy: {accuracy}')

# Make predictions on the entire dataset
predictions = model.predict(encoded_features)

# Convert predictions from probabilities to class labels
predicted_classes = encoder.inverse_transform(predictions)

# Convert true labels from one-hot encoded format to class labels
true_classes = encoder.inverse_transform(encoded_labels)

# Print a few examples of predictions and true labels
for i in range(10):
    print(f"True: {true_classes[i]}, Predicted: {predicted_classes[i]}")

# Convert predicted_classes to a suitable format for DataFrame
predicted_classes_series = pd.Series([pred[0] for pred in predicted_classes], name='Predicted SP')

# Save predictions to a new CSV file
output_df = df.copy()
output_df['Predicted SP'] = predicted_classes_series
output_df.to_csv('nn_predicted_data.csv', index=False)

# Initialize SHAP explainer with summarized background data
# Use shap.sample to summarize the background data to 100 samples
background = shap.sample(X_train, 100)
explainer = shap.KernelExplainer(model.predict, background)

# Calculate SHAP values for a subset of the validation data
shap_values = explainer.shap_values(X_val[:100])

# Plot the SHAP values
shap.summary_plot(shap_values, X_val[:100], feature_names=df.columns[:encoded_features.shape[1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Epoch 1/50
# 200/200 [==============================] - 2s 3ms/step - loss: 1.0753 - accuracy: 0.4081 - val_loss: 1.0502 - val_accuracy: 0.4281
# Epoch 2/50
# 200/200 [==============================] - 0s 2ms/step - loss: 1.0489 - accuracy: 0.4491 - val_loss: 1.0387 - val_accuracy: 0.4538
# Epoch 3/50
# 200/200 [==============================] - 0s 2ms/step - loss: 1.0365 - accuracy: 0.4622 - val_loss: 1.0271 - val_accuracy: 0.4719
# Epoch 4/50
# ...

# %% [markdown]
# ### K-L Divergence

# %%
import pandas as pd
import numpy as np
from scipy.stats import entropy
import glob

# Load the original data
original_df = pd.read_csv('bayesian_network_data_Forward_sampling.csv')

# Get the distribution of SP from the original data
original_distribution = original_df['SP'].value_counts(normalize=True).sort_index()

# Initialize a list to store K-L divergence results
kl_results = []

# Iterate over each neural network prediction file
for file in glob.glob("nn_predictions_layers_*_neurons_*.csv"):
    # Load the neural network predictions
    nn_df = pd.read_csv(file)

    # Get the distribution of SP from the neural network predictions
    nn_distribution = nn_df['Predicted SP'].value_counts(normalize=True).sort_index()

    # Ensure both distributions have the same categories and order
    categories = sorted(set(original_distribution.index).union(set(nn_distribution.index)))
    original_distribution_reindexed = original_distribution.reindex(categories, fill_value=0)
    nn_distribution_reindexed = nn_distribution.reindex(categories, fill_value=0)

    # Calculate the Kullback-Leibler divergence
    kl_divergence = entropy(original_distribution_reindexed, nn_distribution_reindexed)

    # Store the results
    kl_results.append((file, kl_divergence))

# Print the K-L divergence for each model
for file, kl_divergence in kl_results:
    print(f"Kullback-Leibler Divergence for {file}: {kl_divergence}")

# Find and print the model with the smallest K-L divergence
best_model_file, best_kl_divergence = min(kl_results, key=lambda x: x[1])
print(f"\nModel with the smallest Kullback-Leibler Divergence: {best_model_file} with K-L divergence of {best_kl_divergence}")
# Out:
# Kullback-Leibler Divergence for nn_predictions_layers_3_neurons_30.csv: 0.07953601354730176
# Kullback-Leibler Divergence for nn_predictions_layers_2_neurons_30.csv: 0.12921500040810627
# Kullback-Leibler Divergence for nn_predictions_layers_3_neurons_20.csv: 0.10439108292802528
# Kullback-Leibler Divergence for nn_predictions_layers_1_neurons_20.csv: 0.2966280538009843
# Kullback-Leibler Divergence for nn_predictions_layers_2_neurons_20.csv: 0.22118590999976256
# Kullback-Leibler Divergence for nn_predictions_layers_2_neurons_10.csv: 0.2979647906128221
# Kullback-Leibler Divergence for nn_predictions_layers_1_neurons_10.csv: 0.4648798513875537
# Kullback-Leibler Divergence for nn_predictions_layers_1_neurons_30.csv: 0.20293006965444582
# Kullback-Leibler Divergence for nn_predictions_layers_3_neurons_10.csv: 0.6132022067172571
#
# Model with the smallest Kullback-Leibler Divergence: nn_predictions_layers_3_neurons_30.csv with K-L divergence of 0.07953601354730176

# %% [markdown]
# #### Explanations

# %% [markdown]
# ##### The Kullback-Leibler (K-L) divergence measures how one probability distribution diverges from a second, expected probability distribution. In this context, it is used to compare the distribution of the predicted data by the neural networks to the original data distribution.
#
# A lower K-L divergence value indicates that the predicted distribution is closer to the original distribution, meaning the neural network model has captured the variable associations more accurately.
#
# Here are your results, interpreted:
#
# - **Lowest K-L Divergence** (Best match to original distribution):
#   - `nn_predictions_layers_3_neurons_30.csv`: 0.079536
#   - This model with 3 layers and 30 neurons per layer had the best performance in capturing the original data distribution.
#
# - **Second Best**:
#   - `nn_predictions_layers_2_neurons_30.csv`: 0.129215
#   - This model with 2 layers and 30 neurons per layer was the second best.
#
# - **Third Best**:
#   - `nn_predictions_layers_3_neurons_20.csv`: 0.104391
#   - This model with 3 layers and 20 neurons per layer was the third best.
#
# - **Other Models**:
#   - The models with higher K-L divergence values performed worse in capturing the original data distribution. Specifically:
#     - `nn_predictions_layers_1_neurons_20.csv`: 0.296628
#     - `nn_predictions_layers_2_neurons_20.csv`: 0.221186
#     - `nn_predictions_layers_2_neurons_10.csv`: 0.297965
#     - `nn_predictions_layers_1_neurons_10.csv`: 0.464880
#     - `nn_predictions_layers_1_neurons_30.csv`: 0.202930
#     - `nn_predictions_layers_3_neurons_10.csv`: 0.613202
#
# ### Conclusion
# - The model with **3 layers and 30 neurons per layer** (`nn_predictions_layers_3_neurons_30.csv`) performed the best in terms of K-L divergence.
# - The lower the K-L divergence value, the better the model's predicted data distribution matches the original data distribution.
# - Models with fewer layers and neurons generally performed worse compared to those with more layers and neurons in this case.
#
# These results suggest that more complex models (with more layers and neurons) were better at capturing the variable associations present in the original data.
#
# The Kullback-Leibler (K-L) divergence calculation you performed compares the distributions of the **`SP`** and **`Predicted SP`** values. Specifically, it compares the probability distributions of the true class labels (SP) with the predicted class labels (Predicted SP).
#
# Here is the breakdown:
#
# 1. **Original Data (`SP` column)**: This is the true class distribution from your dataset.
# 2. **Predicted Data (`Predicted SP` column)**: This is the predicted class distribution generated by the neural network model.
#
# The K-L divergence measures how the predicted class distribution diverges from the true class distribution. It does not compare the entire dataset's feature distributions, but rather focuses on the target variable `SP` and how well the neural network's predictions align with the actual `SP` values.
#
# So, the comparison is specifically between the **true class labels** (`SP`) and the **predicted class labels** (`Predicted SP`), and not the entire dataset.
#
# Sure, let's walk through an example of calculating Kullback-Leibler (K-L) divergence manually using a small set of true class labels and predicted class labels.
#
# ### Step-by-Step Calculation of K-L Divergence
#
# **Step 1: Define the True and Predicted Distributions**
#
# Let's say we have 5 true class labels (SP) and 5 predicted class labels (Predicted SP). We'll work with a simple binary classification problem where the classes are `0` and `1`.
#
# - True class labels (SP): [0, 1, 1, 0, 1]
# - Predicted class labels (Predicted SP): [0, 0, 1, 0, 1]
#
# **Step 2: Calculate the Probability Distributions**
#
# Calculate the probabilities for each class in both the true and predicted distributions.
#
# **True Distribution (P)**:
# - P(0) = Number of 0s in true labels / Total number of labels = 2 / 5 = 0.4
# - P(1) = Number of 1s in true labels / Total number of labels = 3 / 5 = 0.6
#
# **Predicted Distribution (Q)**:
# - Q(0) = Number of 0s in predicted labels / Total number of labels = 3 / 5 = 0.6
# - Q(1) = Number of 1s in predicted labels / Total number of labels = 2 / 5 = 0.4
#
# **Step 3: Apply the K-L Divergence Formula**
#
# The K-L divergence from distribution Q to distribution P is calculated as follows:
#
# \[ D_{KL}(P || Q) = \sum_{i} P(i) \log \left(\frac{P(i)}{Q(i)}\right) \]
#
# Here, `i` represents each class (`0` and `1`).
#
# **Step 4: Calculate K-L Divergence**
#
# Calculate the divergence for each class and sum the results.
#
# For class `0`:
# \[ P(0) \log \left(\frac{P(0)}{Q(0)}\right) = 0.4 \log \left(\frac{0.4}{0.6}\right) \]
#
# For class `1`:
# \[ P(1) \log \left(\frac{P(1)}{Q(1)}\right) = 0.6 \log \left(\frac{0.6}{0.4}\right) \]
#
# **Step 5: Compute Logarithms and Final Summation**
#
# Let's calculate the logarithms (using natural log):
#
# For class `0`:
# \[ \log \left(\frac{0.4}{0.6}\right) = \log (0.6667) = -0.405 \]
# \[ 0.4 \times -0.405 = -0.162 \]
#
# For class `1`:
# \[ \log \left(\frac{0.6}{0.4}\right) = \log (1.5) = 0.405 \]
# \[ 0.6 \times 0.405 = 0.243 \]
#
# Sum the results:
# \[ D_{KL}(P || Q) = -0.162 + 0.243 = 0.081 \]
#
# So, the Kullback-Leibler divergence for this example is approximately **0.081**.
#
# ### Summary
#
# In this example, we manually calculated the K-L divergence between two distributions by:
# 1. Defining the true and predicted class labels.
# 2. Calculating the probability distributions for each class.
# 3. Applying the K-L divergence formula.
# 4. Summing the results to get the final divergence value.
#
# This demonstrates how the K-L divergence quantifies the difference between the true class distribution and the predicted class distribution.
